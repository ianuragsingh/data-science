# %%
## Exercise GroupBy and Aggregation

# %%
import pandas as pd

# %%
listings = pd.read_csv("listings.csv")
print(listings.shape)
# Out:
# (15778, 75)

# %%
listings.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   18674   https://www.airbnb.com/rooms/18674  20221211170659   2022-12-11
# 1  124342  https://www.airbnb.com/rooms/124342  20221211170659   2022-12-11
# 2  128463  https://www.airbnb.com/rooms/128463  20221211170659   2022-12-12
# 3  130227  https://www.airbnb.com/rooms/130227  20221211170659   2022-12-11
# 4  135513  https://www.airbnb.com/rooms/135513  20221211170659   2022-12-11
#
#         source                                             name  \
# 0  city scrape  Huge flat for 8 people close to Sagrada Familia
# 1  city scrape  BORN CENTRICO / MUSEO PICASSO / 10 min to BEACH
# 2  city scrape              Private Suite in residential area!!
# 3  city scrape              Spacious Room with Pool and Terrace
# 4  city scrape          APARTMENT AT RAMBLA POBLE NOU AND BEACH
#
#                                          description  \
# 0  110m2 apartment to rent in Barcelona. Located ...
# 1  Double room at El Born  / MONTHLY RENTAL & DAY...
# 2  My House is located in the quiet district of S...
# 3  Just 5 minutes’ walk from the beach in the San...
# 4  AMAZING APARTMENT AT RAMBLA OF POBLE NOU ; ONL...
#
#                                neighborhood_overview  \
# 0  Apartment in Barcelona located in the heart of...
# 1                                                NaN
# 2  You live in a typical Spanish district with no...
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/13031453/413c...    71615  ...
# 1  https://a0.muscache.com/pictures/6058611/f5160...   548084  ...
# 2  https://a0.muscache.com/pictures/855084/c71b65...   635253  ...
# 3  https://a0.muscache.com/pictures/14284828/d2ea...   641496  ...
# 4  https://a0.muscache.com/pictures/9578738/40581...   664196  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.69                   4.81                4.28
# 1                        4.88                   4.95                4.49
# 2                        4.90                   4.73                4.82
# 3                        4.78                   4.73                4.64
# 4                        4.80                   4.83                4.56
#
#        license instant_bookable calculated_host_listings_count  \
# 0  HUTB-002062                t                             20
# 1  HUTB-123456                f                              1
# 2  HUTB-012603                t                              1
# 3       Exempt                f                              1
# 4          NaN                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                          20
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.28
# 1                                           0              0.56
# 2                                           0              2.53
# 3                                           0              1.24
# 4                                           0              0.96
#
# [5 rows x 75 columns]

# %%
listings[
    ["price","host_response_rate","host_acceptance_rate"]
].head()
# Out:
#      price host_response_rate host_acceptance_rate
# 0  $129.00               100%                  94%
# 1   $60.00                60%                  43%
# 2   $60.00               100%                 100%
# 3   $80.00                NaN                 100%
# 4   $90.00                83%                  18%

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-8def1d5c30e2> in <module>
# ----> 1 listings["price"] = listings["price"].str[1:].str.replace(",","").astype("float")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
#     172         # Replace the property with the accessor object. Inspired by:
#     173         # http://www.pydanny.com/cached-property.html
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py in __init__(self, data)
#    1794
#    1795     def __init__(self, data):
# -> 1796         self._validate(data)
#    1797         self._is_categorical = is_categorical_dtype(data)
#    1798
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py in _validate(data)
#    1816             # (instead of test for object dtype), but that isn't practical for
#    1817             # performance reasons until we have a str dtype (GH 9343)
# -> 1818             raise AttributeError("Can only use .str accessor with string "
#    1819                                  "values, which use np.object_ dtype in "
#    1820                                  "pandas")
#
# AttributeError: Can only use .str accessor with string values, which use np.object_ dtype in pandas

# %%
listings["price"]
# Out:
# 0        129.00
# 1         60.00
# 2         60.00
# 3         80.00
# 4         90.00
# 5        195.00
# 6         40.00
# 7         73.00
# 8         74.00
# 9        309.00
# 10        60.00
# 11        44.00
# 12       174.00
# 13        40.00
# 14        36.00
# 15        18.00
# 16        60.00
# 17       121.00
# 18        32.00
# 19        38.00
# 20       149.00
# 21        73.00
# 22       103.00
# 23       124.00
# 24       138.00
# 25       115.00
# 26       290.00
# 27       200.00
# 28        80.00
# 29        23.00
#           ...
# 15748     39.00
# 15749    138.00
# 15750     24.00
# 15751     96.00
# 15752     67.00
# 15753    209.00
# 15754    209.00
# 15755    111.00
# 15756    174.00
# 15757    245.00
# 15758    308.00
# 15759     94.00
# 15760     74.00
# 15761     55.00
# 15762     49.00
# 15763    550.00
# 15764    124.00
# 15765    103.00
# 15766    144.00
# 15767     73.00
# 15768    100.00
# 15769     22.00
# 15770     32.00
# 15771     28.00
# 15772     65.00
# 15773     80.00
# 15774    103.00
# 15775    103.00
# 15776    153.00
# 15777    103.00
# Name: price, Length: 15778, dtype: object
